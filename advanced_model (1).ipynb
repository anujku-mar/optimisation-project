# %% [markdown]
# ### 1. Setup and Imports

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from scipy.linalg import expm
from typing import Dict, Tuple, List
import copy
import time

# %% [markdown]
# ### 2. Mission Graph and Phase Logic
# Defining the phase transitions (1 -> 2 -> 3 -> 4) and the rescue branch (R). Phase dependencies indicate which components must survive to pass the phase.

# %%
mission_diagram = {
    '1': {'success': '2', 'fail': 'R'},
    '2': {'success': '3', 'fail': 'R'},
    '3': {'success': '4', 'fail': 'R'},
    '4': {'success': 2,   'fail': 'R'},   # 2 = Mission Success
    'R': {'success': 1,   'fail': 0}      # 1 = Crew Saved, 0 = Total Loss
}

phase_component_logic = {
    '1': [{'A': 'survive', 'B': 'survive'}],
    '2': [{'A': 'survive', 'C': 'survive'}],
    '3': [{'A': 'survive', 'C': 'survive'}],
    '4': [{'A': 'survive', 'D': 'survive'}],
    'R': [{'E': 'survive', 'F': 'survive'}]
}

# %% [markdown]
# ### 3. Dynamic Path Generator
# Uses DFS to dynamically generate temporal boolean paths for the Markov engine, eliminating the need to hardcode BDD logic.

# %%
class DynamicPathGenerator:
    def __init__(self, mission_graph: Dict, phase_bdds: Dict):
        self.mission_graph = mission_graph
        self.phase_bdds = phase_bdds
        self.final_paths = {2: [], 1: [], 0: []}

    def _merge_conditions(self, current_path: Dict, new_phase: str, phase_reqs: Dict, is_phase_success: bool) -> Dict:
        new_path = copy.deepcopy(current_path)
        for comp, state in phase_reqs.items():
            if comp not in new_path:
                new_path[comp] = {'survives': [], 'fails': []}
            if state == 'survive':
                new_path[comp]['survives'].append(new_phase)
            elif state == 'fail':
                new_path[comp]['fails'].append(new_phase)

        if not is_phase_success:
            for comp, state in phase_reqs.items():
                if state == 'survive' and new_phase not in new_path[comp]['fails']:
                    new_path[comp]['fails'].append(new_phase)
        return new_path

    def generate_paths(self, current_phase: str, current_path: Dict = None):
        if current_path is None: current_path = {}

        if current_phase in [2, 1, 0]:
            clean_path = {c: {k: v for k, v in reqs.items() if v} for c, reqs in current_path.items()}
            self.final_paths[current_phase].append(clean_path)
            return

        transitions = self.mission_graph.get(current_phase, {})
        bdds = self.phase_bdds.get(current_phase, [])

        if 'success' in transitions:
            for bdd_path in bdds:
                next_path = self._merge_conditions(current_path, current_phase, bdd_path, True)
                self.generate_paths(transitions['success'], next_path)

        if 'fail' in transitions:
            for bdd_path in bdds:
                next_path = self._merge_conditions(current_path, current_phase, bdd_path, False)
                self.generate_paths(transitions['fail'], next_path)

        return self.final_paths

# %% [markdown]
# ### 4. Advanced Hardware Specifications
# Incorporates Cascading Failures (`gamma`), Phase Transition Shocks (`shock_p`), and continuous online maintenance parameters (`mu_c`, `mu_s`, `rho_rev`).

# %%
phase_durations = {'1': 100.0, '2': 50.0, '3': 150.0, '4': 100.0, 'R': 50.0}

component_specs = {
    'A': {'K': 4, 'lambda_c': 1/1500, 'weight': 5.0,  'cost': 10.0, 'gamma': 1.5, 'shock_p': 0.05, 'mu_c': 1/200, 'mu_s': 1/1000, 'rho_rev': 0.1, 'lambda_s': 1/5000, 'rho_fail': 0.005},
    'B': {'K': 1, 'lambda_c': 1/1200, 'weight': 20.0, 'cost': 15.0, 'gamma': 1.2, 'shock_p': 0.02, 'mu_c': 1/500, 'mu_s': 1/2000, 'rho_rev': 0.05, 'lambda_s': 1/8000, 'rho_fail': 0.001},
    'C': {'K': 1, 'lambda_c': 1/1535, 'weight': 10.0, 'cost': 8.0,  'gamma': 1.8, 'shock_p': 0.08, 'mu_c': 1/300, 'mu_s': 1/1500, 'rho_rev': 0.08, 'lambda_s': 1/4000, 'rho_fail': 0.020},
    'D': {'K': 1, 'lambda_c': 1/1800, 'weight': 15.0, 'cost': 12.0, 'gamma': 1.3, 'shock_p': 0.03, 'mu_c': 1/400, 'mu_s': 1/1800, 'rho_rev': 0.06, 'lambda_s': 1/6000, 'rho_fail': 0.008},
    'E': {'K': 5, 'lambda_c': 1/1200, 'weight': 25.0, 'cost': 20.0, 'gamma': 1.4, 'shock_p': 0.05, 'mu_c': 1/250, 'mu_s': 1/1200, 'rho_rev': 0.15, 'lambda_s': 1/5500, 'rho_fail': 0.010},
    'F': {'K': 1, 'lambda_c': 1/1200, 'weight': 25.0, 'cost': 20.0, 'gamma': 1.1, 'shock_p': 0.01, 'mu_c': 1/800, 'mu_s': 1/3000, 'rho_rev': 0.02, 'lambda_s': 1/9000, 'rho_fail': 0.002}
}

# %% [markdown]
# ### 5. State-Dependent Markov Engine (Birth-Death Process)
# Unlike standard models that assume hardware is non-repairable, this engine simulates **Online Maintenance** using a state-dependent net-rate matrix.
# * **Active Phases (Simultaneous Wear & Repair):** $Q_{net} = Q_{damage} + Q_{repair}$
# * **Idle Phases (System Recovery):** $Q_{net} = Q_{repair}$
# Phase boundary shocks are applied as discrete interventions: $P_{i+1}(0) = P_i(t) \cdot S$

# %%
class Advanced_PMS_Engine:
    def __init__(self, component_specs, phase_durations, state_paths):
        self.component_specs = component_specs
        self.phase_durations = phase_durations
        self.state_paths = state_paths

    def check_constraints(self, particle: Dict, w_max: float, c_max: float) -> bool:
        total_w, total_c = 0.0, 0.0
        for c, n in particle.items():
            total_parts = self.component_specs[c]['K'] + n[0] + n[1]
            total_w += self.component_specs[c]['weight'] * total_parts
            total_c += self.component_specs[c]['cost'] * total_parts
            if n[2] > n[0]: return False
        return total_w <= w_max and total_c <= c_max

    def _build_base_matrices(self, comp_id: str, n_H: int, n_C: int, n_o: int) -> Tuple[np.ndarray, np.ndarray, int]:
        specs = self.component_specs[comp_id]
        size = n_H + n_C + 2
        Q_dam = np.zeros((size, size))
        Q_rep = np.zeros((size, size))

        for i in range(size - 1):
            active_units = min(specs['K'] + n_H, specs['K'] + n_H + n_C - i)
            fail_rate = (specs['lambda_c'] * active_units * (specs.get('gamma', 1.0) ** i)) + (specs.get('lambda_s', 0.0) * n_o)

            if i >= n_H and n_C > 0 and i < n_H + n_C:
                Q_dam[i, i+1] = fail_rate * (1.0 - specs.get('rho_fail', 0.0))
                Q_dam[i, -1] += fail_rate * specs.get('rho_fail', 0.0)
            else:
                Q_dam[i, i+1] = fail_rate

        for i in range(1, size):
            repair_rate = specs.get('mu_c', 0.0) + (specs.get('mu_s', 0.0) if i > n_H else 0.0)

            if i == size - 1:
                Q_rep[i, i-1] = repair_rate * specs.get('rho_rev', 0.0)
            else:
                Q_rep[i, i-1] = repair_rate

        return Q_dam, Q_rep, size

    def _build_shock_matrix(self, comp_id: str, size: int) -> np.ndarray:
        shock_p = self.component_specs[comp_id].get('shock_p', 0.0)
        S = np.zeros((size, size))
        for i in range(size - 1):
            S[i, i] = 1.0 - shock_p
            S[i, i+1] = shock_p
        S[-1, -1] = 1.0
        return S

    def evaluate_path_probability(self, path_reqs: Dict, particle: Dict) -> float:
        path_prob = 1.0
        mission_order = ['1', '2', '3', '4', 'R']

        for comp_id, conditions in path_reqs.items():
            if comp_id not in particle: continue

            n_H, n_C, n_o = particle[comp_id]
            Q_dam, Q_rep, size = self._build_base_matrices(comp_id, n_H, n_C, n_o)
            S = self._build_shock_matrix(comp_id, size)

            P_current = np.zeros(size)
            P_current[0] = 1.0

            all_req_phases = conditions.get('survives', []) + conditions.get('fails', [])
            if not all_req_phases: continue
            last_req_idx = max(mission_order.index(p) for p in all_req_phases)

            for i in range(last_req_idx + 1):
                phase = mission_order[i]
                t = self.phase_durations[phase]

                if i > 0:
                    P_current = np.dot(P_current, S)

                is_active = phase in conditions.get('survives', [])

                if is_active:
                    Q_net = Q_dam + Q_rep
                else:
                    Q_net = Q_rep.copy()

                for row in range(size):
                    Q_net[row, row] = 0
                    Q_net[row, row] = -np.sum(Q_net[row, :])

                P_current = np.dot(P_current, expm(Q_net * t))

                if phase in conditions.get('fails', []):
                    path_prob *= max(P_current[-1], 0.0)
                    break

            if not conditions.get('fails', []):
                path_prob *= max(1.0 - P_current[-1], 0.0)

        return max(path_prob, 0.0)

    def calculate_system_csp(self, particle: Dict, max_weight: float, max_cost: float) -> float:
        if not self.check_constraints(particle, max_weight, max_cost): return 0.0
        p_sys_2 = sum(self.evaluate_path_probability(path, particle) for path in self.state_paths.get(2, []))
        p_sys_1 = sum(self.evaluate_path_probability(path, particle) for path in self.state_paths.get(1, []))
        return min(p_sys_2 + p_sys_1, 1.0)

# %% [markdown]
# ### 6. Optimizer & Main Execution Block
# *(Note: The PSO function logic remains identical to the baseline to ensure fair optimization testing).*

# %%
def run_advanced_pso(engine, num_particles=30, max_iter=40, w=0.5, c1=1.5, c2=1.5, max_weight=230.0, max_cost=220.0):
    start_time = time.time()
    component_ids = list(engine.component_specs.keys())

    swarm, velocities, pbest_positions, pbest_scores = [], [], [], []
    history = []

    base_config = {c: (0, 0, 0) for c in component_ids}
    gbest_position = base_config.copy()
    gbest_score = engine.calculate_system_csp(base_config, max_weight, max_cost)

    for i in range(num_particles):
        p_dict = {}
        for c in component_ids:
            if i == 0:
                p_dict[c] = (0, 0, 0)
            else:
                nH = random.randint(0, 1)
                nC = random.randint(0, 1)
                n_o = random.randint(0, nH)
                p_dict[c] = (nH, nC, n_o)

        swarm.append(p_dict)
        velocities.append([[0.0, 0.0, 0.0] for _ in component_ids])
        pbest_positions.append(p_dict.copy())
        pbest_scores.append(0.0)

    for iteration in range(max_iter):
        for i in range(num_particles):
            fitness = engine.calculate_system_csp(swarm[i], max_weight, max_cost)
            if fitness > pbest_scores[i]:
                pbest_scores[i] = fitness
                pbest_positions[i] = swarm[i].copy()
            if fitness > gbest_score:
                gbest_score = fitness
                gbest_position = swarm[i].copy()

        history.append(gbest_score)

        for i in range(num_particles):
            new_p = {}
            for j, c in enumerate(component_ids):
                curr, pbest, gbest = swarm[i][c], pbest_positions[i][c], gbest_position[c]
                new_pos = []
                for k in range(3):
                    r1, r2 = random.random(), random.random()
                    velocities[i][j][k] = (w * velocities[i][j][k] +
                                           c1 * r1 * (pbest[k] - curr[k]) +
                                           c2 * r2 * (gbest[k] - curr[k]))
                    val = max(0, int(round(curr[k] + velocities[i][j][k])))
                    new_pos.append(val)

                if new_pos[2] > new_pos[0]:
                    new_pos[2] = new_pos[0]

                new_p[c] = tuple(new_pos)
            swarm[i] = new_p

    exec_time = time.time() - start_time
    return gbest_position, gbest_score, history, exec_time

if __name__ == "__main__":
    print("1. Generating Paths via DFS...")
    generator = DynamicPathGenerator(mission_diagram, phase_component_logic)
    dynamic_paths = generator.generate_paths(current_phase='1')

    print("2. Initializing Advanced Engine...")
    advanced_engine = Advanced_PMS_Engine(component_specs, phase_durations, dynamic_paths)

    print("3. Starting Advanced Optimization...")
    best_config, best_csp, history, exec_time = run_advanced_pso(
        engine=advanced_engine, num_particles=30, max_iter=40, max_weight=230.0, max_cost=220.0
    )

    print(f"\nOptimization Complete in {exec_time:.2f}s")
    print(f"Max Crew Survival Probability: {best_csp:.6f}")
    for comp, config in best_config.items():
        print(f"  Component {comp}: Hot={config[0]}, Cold={config[1]}, Online={config[2]}")

    print(f"\nOptimization Complete in {exec_time:.2f}s")
    print(f"Max Crew Survival Probability: {best_csp:.6f}")

    # --- NEW: Calculate final weight and cost ---
    final_weight, final_cost = 0.0, 0.0
    for comp, config in best_config.items():
        print(f"  Component {comp}: Hot={config[0]}, Cold={config[1]}, Online={config[2]}")
        # Note: Change 'advanced_engine' to 'baseline_engine' if pasting this into the baseline file
        total_parts = advanced_engine.component_specs[comp]['K'] + config[0] + config[1]
        final_weight += advanced_engine.component_specs[comp]['weight'] * total_parts
        final_cost += advanced_engine.component_specs[comp]['cost'] * total_parts

    print(f"\nFinal System Weight: {final_weight} / 230.0 kg")
    print(f"Final System Cost:   {final_cost} / 220.0 M")

    # --- UPGRADED GRAPHICS ---
    plt.style.use('seaborn-v0_8-darkgrid')
    fig, ax = plt.subplots(figsize=(10, 6), dpi=120)

    ax.plot(range(1, len(history) + 1), history, marker='o', markersize=6, linewidth=2, color='#d62728', label='APSO Best CSP')
    ax.fill_between(range(1, len(history) + 1), history, alpha=0.1, color='#d62728')

    ax.set_title('Advanced System Convergence: Birth-Death & Transition Shocks', fontsize=14, fontweight='bold', pad=15)
    ax.set_xlabel('Optimization Iteration', fontsize=12, fontweight='bold')
    ax.set_ylabel('Crew Survival Probability (CSP)', fontsize=12, fontweight='bold')
    ax.legend(loc='lower right', fontsize=11, frameon=True, shadow=True)
    plt.tight_layout()
    plt.show()
# Out:
# 1. Generating Paths via DFS...
# 2. Initializing Advanced Engine...
# 3. Starting Advanced Optimization...
#
# Optimization Complete in 13.19s
# Max Crew Survival Probability: 0.586537
#   Component A: Hot=0, Cold=1, Online=0
#   Component B: Hot=0, Cold=0, Online=0
#   Component C: Hot=0, Cold=1, Online=0
#   Component D: Hot=0, Cold=0, Online=0
#   Component E: Hot=0, Cold=0, Online=0
#   Component F: Hot=0, Cold=0, Online=0
#
# Optimization Complete in 13.19s
# Max Crew Survival Probability: 0.586537
#   Component A: Hot=0, Cold=1, Online=0
#   Component B: Hot=0, Cold=0, Online=0
#   Component C: Hot=0, Cold=1, Online=0
#   Component D: Hot=0, Cold=0, Online=0
#   Component E: Hot=0, Cold=0, Online=0
#   Component F: Hot=0, Cold=0, Online=0
#
# Final System Weight: 230.0 / 230.0 kg
# Final System Cost:   213.0 / 220.0 M
